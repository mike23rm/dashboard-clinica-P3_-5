# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\mayk_\Documents\Jupyter\clinical_analytics.csv")
print(data.shape)
data.head()
# Out:
# (81667, 13)
#      Admit Source Admit Type         Appt Start Time  Care Score  \
# 0  Emergency Room  Emergency  2014-01-02 11:38:50 PM           2
# 1  Emergency Room  Emergency  2014-01-02 11:44:18 PM           2
# 2  Emergency Room  Emergency  2014-01-02 11:47:11 PM           2
# 3  Emergency Room  Emergency  2014-01-08 10:38:04 PM           4
# 4  Emergency Room  Emergency  2014-01-09 12:00:26 AM           4
#
#             Check-In Time     Clinic Name  Department Diagnosis Primary  \
# 0  2014-01-02 11:24:00 PM  Madison Center  Cardiology               NaN
# 1  2014-01-02 11:24:00 PM  Madison Center  Cardiology               NaN
# 2  2014-01-02 11:24:00 PM  Madison Center  Cardiology               NaN
# 3   2014-01-08 9:00:00 PM  Madison Center   Emergency               NaN
# 4  2014-01-08 10:47:00 PM  Madison Center   Emergency               NaN
#
#   Discharge Datetime new Encounter Number Encounter Status  Number of Records  \
# 0                    NaN        P7P4KC587        Cancelled                  1
# 1                    NaN        P7P4KC587        Cancelled                  1
# 2                    NaN        P7P4KC587        Cancelled                  1
# 3                    NaN        PK559C587        Cancelled                  1
# 4                    NaN        48559C587        Cancelled                  1
#
#    Wait Time Min
# 0             14
# 1             20
# 2             23
# 3             98
# 4             73

# %%
data["Admit Source"].unique()
# Out:
# array(['Emergency Room', 'Clinic Referral', 'Physician Referral', nan,
#        'Outside Health Care Facility',
#        'Admitted as transfer from another unit', 'Court/Law Enforcement',
#        'Outside Hospital', 'Transfer from Critical Access Hospital',
#        'Outside Home Health Agency', 'Information Unavailable',
#        'Psych, Substance Abuse, or Rehab Hospital'], dtype=object)

# %%
data["Encounter Status"].unique()
# Out:
# array(['Cancelled', 'Admit', 'Preadmit', 'ED Discharged', 'Discharged',
#        'Inpatient Discharged', 'OBS Discharged', 'Day Surg Discharged',
#        nan], dtype=object)

# %%
data["Number of Records"].unique()
# Out:
# array([1])

# %%
data["Department"].unique()
# Out:
# array(['Cardiology', 'Emergency', 'Ophthalmology', 'Oral Surgery',
#        'General Surgery', 'Neurosurgery', 'Urology', 'Otolaryngology',
#        'Gastroenterology', 'Plastic Surgery', 'Neurology',
#        'General Medicine', 'Rehabilitation', 'Nephrology',
#        'Dental Surgery', 'Orthopedics', 'Cardiac Surgery'], dtype=object)

# %%
pip install dash-bootstrap-components
# Out:
# Collecting dash-bootstrap-components
#   Downloading dash_bootstrap_components-2.0.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: dash>=3.0.4 in c:\users\mayk_\anaconda3\lib\site-packages (from dash-bootstrap-components) (4.0.0)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\users\mayk_\anaconda3\lib\site-packages (from dash>=3.0.4->dash-bootstrap-components) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in c:\users\mayk_\anaconda3\lib\site-packages (from dash>=3.0.4->dash-bootstrap-components) (3.1.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\mayk_\anaconda3\lib\site-packages (from dash>=3.0.4->dash-bootstrap-components) (6.3.0)
# Requirement already satisfied: importlib-metadata in c:\users\mayk_\anaconda3\lib\site-packages (from dash>=3.0.4->dash-bootstrap-components) (8.7.0)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\mayk_\anaconda3\lib\site-packages (from dash>=3.0.4->dash-bootstrap-components) (4.15.0)
# Requirement already satisfied: requests in c:\users\mayk_\anaconda3\lib\site-packages (from dash>=3.0.4->dash-bootstrap-components) (2.32.5)
# Requirement already satisfied: retrying in c:\users\mayk_\anaconda3\lib\site-packages (from dash>=3.0.4->dash-bootstrap-components) (1.4.2)
# Requirement already satisfied: nest-asyncio in c:\users\mayk_\anaconda3\lib\site-packages (from dash>=3.0.4->dash-bootstrap-components) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\mayk_\anaconda3\lib\site-packages (from dash>=3.0.4->dash-bootstrap-components) (80.9.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\mayk_\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=3.0.4->dash-bootstrap-components) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\mayk_\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=3.0.4->dash-bootstrap-components) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\mayk_\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=3.0.4->dash-bootstrap-components) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\mayk_\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=3.0.4->dash-bootstrap-components) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\mayk_\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=3.0.4->dash-bootstrap-components) (3.0.2)
# Requirement already satisfied: colorama in c:\users\mayk_\anaconda3\lib\site-packages (from click>=8.1.3->Flask<3.2,>=1.0.4->dash>=3.0.4->dash-bootstrap-components) (0.4.6)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\mayk_\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=3.0.4->dash-bootstrap-components) (2.7.0)
# Requirement already satisfied: packaging in c:\users\mayk_\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=3.0.4->dash-bootstrap-components) (25.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\mayk_\anaconda3\lib\site-packages (from importlib-metadata->dash>=3.0.4->dash-bootstrap-components) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\mayk_\anaconda3\lib\site-packages (from requests->dash>=3.0.4->dash-bootstrap-components) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mayk_\anaconda3\lib\site-packages (from requests->dash>=3.0.4->dash-bootstrap-components) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\mayk_\anaconda3\lib\site-packages (from requests->dash>=3.0.4->dash-bootstrap-components) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mayk_\anaconda3\lib\site-packages (from requests->dash>=3.0.4->dash-bootstrap-components) (2026.1.4)
# Downloading dash_bootstrap_components-2.0.4-py3-none-any.whl (204 kB)
# Installing collected packages: dash-bootstrap-components
# Successfully installed dash-bootstrap-components-2.0.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import plotly.express as px
from dash import Dash, html, dcc, Input, Output
import dash_bootstrap_components as dbc

# %%
# ================================
# 📥 DATA
# ================================
df = pd.read_csv("clinical_analytics.csv")

# Limpiar nombres de columnas
df.columns = df.columns.str.strip()

# Convertir fecha (corrigiendo warning)
df['Appt Start Time'] = pd.to_datetime(df['Appt Start Time'], errors='coerce')

# ================================
# 🚀 APP
# ================================
app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

# ================================
# 🎨 LAYOUT
# ================================
app.layout = dbc.Container([

    dbc.Row([
        dbc.Col(html.H2("🏥 Dashboard Operativo - Clínica", className="text-center"))
    ]),

    dbc.Row([
        dbc.Col([
            dcc.DatePickerRange(
                id='date_range',
                start_date=df['Appt Start Time'].min(),
                end_date=df['Appt Start Time'].max()
            )
        ], width=4),

        dbc.Col([
            dcc.Dropdown(
                id='clinic_filter',
                options=[{'label': c, 'value': c} for c in df['Clinic Name'].dropna().unique()],
                multi=True,
                placeholder="Selecciona clínicas"
            )
        ], width=4),

        dbc.Col([
            dcc.Dropdown(
                id='source_filter',
                options=[{'label': s, 'value': s} for s in df['Admit Source'].dropna().unique()],
                multi=True,
                placeholder="Fuente de admisión"
            )
        ], width=4),
    ]),

    html.Br(),

    dbc.Row([
        dbc.Col(html.Div(id="kpi_total"), width=4),
        dbc.Col(html.Div(id="kpi_wait"), width=4),
        dbc.Col(html.Div(id="kpi_rating"), width=4),
    ]),

    html.Br(),

    dbc.Row([
        dbc.Col(dcc.Graph(id="volume_chart"), width=4),
        dbc.Col(dcc.Graph(id="wait_chart"), width=4),
        dbc.Col(dcc.Graph(id="rating_chart"), width=4),
    ])

], fluid=True)

# ================================
# 🔄 CALLBACK
# ================================
@app.callback(
    [
        Output("volume_chart", "figure"),
        Output("wait_chart", "figure"),
        Output("rating_chart", "figure"),
        Output("kpi_total", "children"),
        Output("kpi_wait", "children"),
        Output("kpi_rating", "children"),
    ],
    [
        Input("date_range", "start_date"),
        Input("date_range", "end_date"),
        Input("clinic_filter", "value"),
        Input("source_filter", "value"),
    ]
)
def update_dashboard(start, end, clinics, sources):

    dff = df.copy()

    # 🔹 Filtro fecha (evita errores con NaT)
    dff = dff.dropna(subset=['Appt Start Time'])

    if start and end:
        dff = dff[
            (dff['Appt Start Time'] >= start) &
            (dff['Appt Start Time'] <= end)
        ]

    # 🔹 Filtros
    if clinics:
        dff = dff[dff['Clinic Name'].isin(clinics)]

    if sources:
        dff = dff[dff['Admit Source'].isin(sources)]

    # ================================
    # 📊 GRÁFICOS
    # ================================
    fig_volume = px.bar(
        dff,
        x="Clinic Name",
        title="Volumen de Pacientes"
    )

    fig_wait = px.box(
        dff,
        x="Department",
        y="Wait Time Min",
        title="Tiempo de Espera por Departamento"
    )

    fig_rating = px.histogram(
        dff,
        x="Care Score",
        color="Department",
        title="Distribución de Calificación"
    )

    # ================================
    # 📌 KPIs
    # ================================
    total = len(dff)
    avg_wait = round(dff['Wait Time Min'].mean(), 2)
    avg_rating = round(dff['Care Score'].mean(), 2)

    kpi_total = dbc.Card(dbc.CardBody([
        html.H5("Pacientes"),
        html.H3(total)
    ]))

    kpi_wait = dbc.Card(dbc.CardBody([
        html.H5("Tiempo Promedio"),
        html.H3(avg_wait)
    ]))

    kpi_rating = dbc.Card(dbc.CardBody([
        html.H5("Satisfacción"),
        html.H3(avg_rating)
    ]))

    return fig_volume, fig_wait, fig_rating, kpi_total, kpi_wait, kpi_rating


# ================================
# ▶️ RUN
# ================================
if __name__ == "__main__":
    app.run(debug=True)
# Out:
# C:\Users\mayk_\AppData\Local\Temp\ipykernel_42536\2887038011.py:10: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
